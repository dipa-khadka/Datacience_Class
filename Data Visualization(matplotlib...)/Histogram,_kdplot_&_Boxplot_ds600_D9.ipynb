# %% [markdown]
# # Histogram, Kdeplot and Boxplot

# %%
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['sepal_length']) # histogram ploting
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <BarContainer object of 10 artists>)

# %%
# we can control bin size means we can controm no of bins in histogram
plt.hist(df['sepal_length'] ,bins=5)
# Out:
# (array([32., 41., 42., 24., 11.]),
#  array([4.3 , 5.02, 5.74, 6.46, 7.18, 7.9 ]),
#  <BarContainer object of 5 artists>)

# %%
# using seaborn
sns.histplot(df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
# histogram with kdeplot
sns.histplot(df['sepal_length'] , kde=True) #histogram lai smooth garna ko lagi kde use garne / overal shape dekahauxa
# Out:
# <Axes: xlabel='sepal_length', ylabel='Count'>

# %%
# kdeplot without histogram
sns.kdeplot(df['sepal_length'])
# Out:
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %% [markdown]
# # Boxplot

# %%
plt.boxplot(df['sepal_width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d3d0c73ece0>,
#   <matplotlib.lines.Line2D at 0x7d3d0c73ef80>],
#  'caps': [<matplotlib.lines.Line2D at 0x7d3d0c73f220>,
#   <matplotlib.lines.Line2D at 0x7d3d0c73f4c0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7d3d0c73ea40>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d3d0c73f760>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d3d0c73fa00>],
#  'means': []}

# %%
plt.boxplot(df['sepal_width'])
plt.show()

# %%
#Boxplot using seaborn
sns.boxplot(df['sepal_width'])
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
# sepal_weidth ma marta outlier xa aruma xaina
# data ko distrubution matra dekhako xa

# %%
# data point dekhaune pani
sns.boxplot(df)
sns.stripplot(df)
# Out:
# <Axes: >

# %%
# datapoint using plotly it is optional
import plotly.express as px

# %%
px.box(df.iloc[:, :-1])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1486dfc4-b9ec-4b26-b6a6-c74b6c481c5d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1486dfc4-b9ec-4b26-b6a6-c74b6c481c5d")) {                    Plotly.newPlot(                        "1486dfc4-b9ec-4b26-b6a6-c74b6c481c5d",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_wid ...

# %%
px.box(df.iloc[:, :-1], points='all')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8964a5d8-256e-4ec3-87d1-394ec73a14fb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8964a5d8-256e-4ec3-87d1-394ec73a14fb")) {                    Plotly.newPlot(                        "8964a5d8-256e-4ec3-87d1-394ec73a14fb",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"variable=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_length","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal_width","sepal ...
